# %% [markdown]
# <a href="https://colab.research.google.com/github/kkdongeug/ABCD-A/blob/20250311/Python_Variable_Classic_20250311.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
watch=10000
a = 'pig'
b = 'dad'

print(a)
print(b)
print(watch)
print(a+b)
print(a+' '+b)
# Out:
# pig
# dad
# 10000
# pigdad
# pig dad

# %%
a = 10
a,b = (10, 20)
[a,b] = [10, 20]
a = b = 10
a = None

# %%
a = 10
b = 2000
a,b = b,a

# %%
a = [10, 20, 30]
b = a
a[0] = 200
print(b)
# Out:
# [200, 20, 30]

# %%
print("hello world")

print(1)

a = 1
print(a)
# Out:
# hello world
# 1
# 1

# %%
print("a="+str(a))
print("a=", a)

print( "a={}".format(a) )
# Out:
# a=[200, 20, 30]
# a= [200, 20, 30]
# a=[200, 20, 30]
