# %% [markdown]
# <a href="https://colab.research.google.com/github/kkdongeug/ABCD-A/blob/20250314/Python_10_300.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello world') # 1번 문제
# Out:
# Hello world

# %%
print("Mary's cosmetics") # 2번 문제
# Out:
# Mary's cosmetics

# %%
print('신씨가 소리질렀다. "도둑이야".') # 3번 문제
# Out:
# 신씨가 소리질렀다. "도둑이야".

# %%
print('"C:\\Windows"') # 4번 문제
# Out:
# "C:\Windows"

# %%
print("안녕하세요.\n만나서\t\t반갑습니다.") #5번 문제, \n은 줄내림, \t는 4칸 띄어쓰기
# Out:
# 안녕하세요.
# 만나서		반갑습니다.

# %%
print("오늘은","일요일") # 6번 문제, 중간에 공백이 생기는 것을 확인할 수 있음
# Out:
# 오늘은 일요일

# %%
print("naver;kakao;sk;samsung") # 7번 문제
#또는
print("naver","kakao","sk","samsung", sep=';')
# Out:
# naver;kakao;sk;samsung
# naver;kakao;sk;samsung

# %%
print("naver/kakao/sk/samsung") # 8번 문제
#또는
print("naver","kakao","sk","samsung", sep='/')
# Out:
# naver/kakao/sk/samsung
# naver/kakao/sk/samsung

# %%
print("first",end="");print("second") # 9번 문제
# Out:
# firstsecond

# %%
print("%d", 5/3) # 10번 문제
#또는
print(5/3)
# Out:
# %d 1.6666666666666667
